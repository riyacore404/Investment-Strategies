# %% [markdown]
# ### Dividend Based Investing
# A model that ranks stocks based on their dividend strength using weighted normalized metrics.

# %% [markdown]
# Import the libraries

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import math

# %% [markdown]
# Load The Stocks List

# %%
tickers = pd.read_csv('top50_us_stocks_info.csv')
tickers.head()
# Out:
#                      Name Ticker       Sector     MarketCap  PreviousClose  \
# 0              3M Company    MMM  Industrials   87442300928         160.59
# 1  A.O. Smith Corporation    AOS  Industrials    9207796736          65.15
# 2     Abbott Laboratories    ABT   Healthcare  217098158080         125.80
# 3             AbbVie Inc.   ABBV   Healthcare  383705284608         215.89
# 4           Accenture plc    ACN   Technology  153862651904         242.90
#
#    52WeekHigh  52WeekLow
# 0      172.85     121.98
# 1       77.92      58.83
# 2      141.23     110.86
# 3      244.81     163.81
# 4      398.35     229.40

# %% [markdown]
# Create Dividend DataFrame

# %%
def create_dividend_df(tickers): 
    # Define the columns to store dividend-related data for each stock
    cols = [
        'Ticker',
        'Dividend Yield(%)',
        'Dividend Rate',
        'Payout Ratio',
        'Five Year Avg Dividend Yield(%)',
        'Earning Growth(%)'
    ]

    # Create an empty df with the above columns
    dividend_df = pd.DataFrame(columns=cols)

    for stock in tickers:
        ticker = yf.Ticker(stock)
        info = ticker.info

        # Extract key dividend metrics (convert ratios to % where needed)
        dividend_yield = info.get('dividendYield', np.nan) * 100 if info.get('dividendYield') else np.nan
        dividend_rate = info.get('dividendRate', np.nan)
        payout_ratio = info.get('payoutRatio', np.nan) * 100 if info.get('payoutRatio') else np.nan
        five_year_avg_dividend_yield = info.get('fiveYearAvgDividendYield', np.nan) if info.get('fiveYearAvgDividendYield') else np.nan
        earnings_growth = info.get('earningsGrowth', np.nan) * 100 if info.get('earningsGrowth') else np.nan

        # Append the extracted data as a new row in the df
        dividend_df.loc[len(dividend_df)] = [
            stock,
            dividend_yield,
            dividend_rate,
            payout_ratio,
            five_year_avg_dividend_yield,
            earnings_growth
        ]

    # Columns that will be normalized later
    numeric_cols = {
        'Dividend Yield(%)',
        'Dividend Rate',
        'Payout Ratio',
        'Five Year Avg Dividend Yield(%)',
        'Earning Growth(%)'
    }

    # Define weightage for each normalized metric (used for computing final score)
    # These can be adjusted based on data analysis or investor preference
    weights = {
        'Dividend Yield(%) Normalised': 0.3,
        'Dividend Rate Normalised': 0.2,
        'Payout Ratio Normalised': 0.2,
        'Five Year Avg Dividend Yield(%) Normalised': 0.2,
        'Earning Growth(%) Normalised': 0.1
    }

    # Normalize numeric columns using Min-Max normalization:
    # Normalized value = (value - min) / (max - min)
    for col in numeric_cols :
        dividend_df[col + ' Normalised'] = (dividend_df[col] - dividend_df[col].min()) / (dividend_df[col].max() - dividend_df[col].min())
        
        # For payout ratio, higher values are worse, so we invert the normalized score
        if col == 'Payout Ratio':
            dividend_df[col + ' Normalised'] = 1 - dividend_df[col + ' Normalised']

    return dividend_df

# %%
# Convert the 'Ticker' col from the CSV into a list of stock tickers
tickers_list = tickers['Ticker'].values.tolist()
dividend_df = create_dividend_df(tickers_list)
dividend_df
# Out:
#    Ticker  Dividend Yield(%)  Dividend Rate  Payout Ratio  \
# 0     MMM              178.0           2.92     46.090000
# 1     AOS              209.0           1.38     36.660000
# 2     ABT              189.0           2.36     29.150000
# 3    ABBV              319.0           6.92    490.149970
# 4     ACN              263.0           6.52     48.720002
# 5    ADBE                NaN            NaN           NaN
# 6     AMD                NaN            NaN           NaN
# 7     AES              495.0           0.70     46.080002
# 8     AFL              209.0           2.32     29.430000
# 9       A               68.0           0.99     22.900000
# 10    APD              301.0           7.16    100.990000
# 11   ABNB                NaN            NaN           NaN
# 12   AKAM                NaN            NaN           NaN
# 13    ALB              176.0           1.62     57.970000
# 14    ARE              969.0           5.28    689.469960
# 15   ALGN                NaN            NaN           NaN
# 16   ALLE              123.0           2.04     27.200000
# 17    LNT              304.0           2.03     60.960000
# 18    ALL              205.0           4.00     12.710000
# 19  GOOGL               30.0           0.84      8.090000
# 20   GOOG               29.0           0.84      8.090000
# 21     MO              742.0           4.24     78.629994
# 22   AMZN                NaN            NaN           NaN
# 23   AMCR              632.0           0.51    158.590000
# 24    AEE              280.0           2.84     60.660000
# 25    AEP              317.0           3.80     54.470000
# 26    AXP               86.0           3.16     15.720001
# 27    AIG              236.0           1.80     30.580000
# 28    AMT              379.0           6.80    107.180000
# 29    AWK              253.0           3.31     55.979997
# 30    AMP              139.0           6.40     16.950001
# 31    AME               63.0           1.24     19.090000
# 32   AMGN              298.0           9.52     72.620004
# 33    APH               72.0           1.00     22.000000
# 34    ADI              168.0           3.96     97.199994
# 35    AON               87.0           2.98     22.719999
# 36    APA              462.0           1.00     34.600000
# 37    APO              153.0           2.04     35.400000
# 38   AAPL               38.0           1.04     13.670000
# 39   AMAT               76.0           1.84     19.810000
# 40    APP                NaN            NaN           NaN
# 41   APTV                NaN            NaN           NaN
# 42   ACGL                NaN            NaN           NaN
# 43    ADM              362.0           2.04     87.830000
# 44   ANET                NaN            NaN           NaN
# 45    AJG              105.0           2.60     40.730000
# 46    AIZ              147.0           3.20     19.500000
# 47      T              452.0           1.11     36.160000
# 48    ATO              202.0           3.48     47.230000
# 49   ADSK                NaN            NaN           NaN
#
#     Five Year Avg Dividend Yield(%)  Earning Growth(%)  \
# 0                              4.03              -37.5
# 1                              1.72               14.6
# 2                              1.71                NaN
# 3                              3.78              -88.7
# 4                              1.45              -15.5
# 5                              0.12               11.2
# 6                               NaN               60.3
# 7                              3.55               25.3
# 8                              2.20              -64.2
# 9                              0.66               21.6
# 10                             2.35                2.4
# 11                              NaN                1.6
# 12                              NaN              -17.4
# 13                             1.19                NaN
# 14                             3.91                NaN
# 15                              NaN              -49.7
# 16                             1.35                9.5
# 17                             3.14               99.6
# 18                             2.35              586.7
# 19                              NaN               35.3
# 20                              NaN               35.3
# 21                             7.78                5.2
# 22                              NaN               36.4
# 23                             4.62                NaN
# 24                             2.83                4.4
# 25                             3.57                0.6
# 26                             1.14               18.6
# 27                             2.26               31.0
# 28                             2.71                NaN
# 29                             1.86                8.1
# 30                             1.49               86.6
# 31                             0.62                8.8
# 32                             3.07               13.6
# 33                             0.88              102.1
# 34                             1.71               31.6
# 35                             0.75               34.4
# 36                             2.42               14.5
# 37                             2.45              -26.7
# 38                             0.53               91.2
# 39                             0.82                8.3
# 40                              NaN              168.8
# 41                             1.16                NaN
# 42                              NaN               39.1
# 43                             2.68              489.1
# 44                              NaN               15.0
# 45                             1.04              -25.2
# 46                             1.72              106.1
# 47                             6.63                NaN
# 48                             2.45                7.5
# 49                             0.48               12.3
#
#     Dividend Rate Normalised  Dividend Yield(%) Normalised  \
# 0                   0.267481                      0.158511
# 1                   0.096559                      0.191489
# 2                   0.205327                      0.170213
# 3                   0.711432                      0.308511
# 4                   0.667037                      0.248936
# 5                        NaN                           NaN
# 6                        NaN                           NaN
# 7                   0.021088                      0.495745
# 8                   0.200888                      0.191489
# 9                   0.053274                      0.041489
# 10                  0.738069                      0.289362
# 11                       NaN                           NaN
# 12                       NaN                           NaN
# 13                  0.123196                      0.156383
# 14                  0.529412                      1.000000
# 15                       NaN                           NaN
# 16                  0.169811                      0.100000
# 17                  0.168701                      0.292553
# 18                  0.387347                      0.187234
# 19                  0.036626                      0.001064
# 20                  0.036626                      0.000000
# 21                  0.413984                      0.758511
# 22                       NaN                           NaN
# 23                  0.000000                      0.641489
# 24                  0.258602                      0.267021
# 25                  0.365150                      0.306383
# 26                  0.294118                      0.060638
# 27                  0.143174                      0.220213
# 28                  0.698113                      0.372340
# 29                  0.310766                      0.238298
# 30                  0.653718                      0.117021
# 31                  0.081021                      0.036170
# 32                  1.000000                      0.286170
# 33                  0.054384                      0.045745
# 34                  0.382908                      0.147872
# 35                  0.274140                      0.061702
# 36                  0.054384                      0.460638
# 37                  0.169811                      0.131915
# 38                  0.058824                      0.009574
# 39                  0.147614                      0.050000
# 40                       NaN                           NaN
# 41                       NaN                           NaN
# 42                       NaN                           NaN
# 43                  0.169811                      0.354255
# 44                       NaN                           NaN
# 45                  0.231964                      0.080851
# 46                  0.298557                      0.125532
# 47                  0.066593                      0.450000
# 48                  0.329634                      0.184043
# 49                       NaN                           NaN
#
#     Payout Ratio Normalised  Earning Growth(%) Normalised  \
# 0                  0.944231                      0.075807
# 1                  0.958070                      0.152946
# 2                  0.969092                           NaN
# 3                  0.292524                      0.000000
# 4                  0.940371                      0.108380
# 5                       NaN                      0.147912
# 6                       NaN                      0.220610
# 7                  0.944245                      0.168789
# 8                  0.968681                      0.036275
# 9                  0.978265                      0.163311
# 10                 0.863659                      0.134883
# 11                      NaN                      0.133699
# 12                      NaN                      0.105567
# 13                 0.926796                           NaN
# 14                 0.000000                           NaN
# 15                      NaN                      0.057744
# 16                 0.971954                      0.145395
# 17                 0.922407                      0.278798
# 18                 0.993220                      1.000000
# 19                 1.000000                      0.183595
# 20                 1.000000                      0.183595
# 21                 0.896475                      0.139029
# 22                      NaN                      0.185224
# 23                 0.779125                           NaN
# 24                 0.922848                      0.137844
# 25                 0.931932                      0.132218
# 26                 0.988802                      0.158869
# 27                 0.966993                      0.177228
# 28                 0.854575                           NaN
# 29                 0.929716                      0.143322
# 30                 0.986997                      0.259550
# 31                 0.983856                      0.144359
# 32                 0.905295                      0.151466
# 33                 0.979586                      0.282499
# 34                 0.869221                      0.178117
# 35                 0.978529                      0.182262
# 36                 0.961094                      0.152798
# 37                 0.959920                      0.091797
# 38                 0.991811                      0.266361
# 39                 0.982800                      0.143619
# 40                      NaN                      0.381256
# 41                      NaN                           NaN
# 42                      NaN                      0.189221
# 43                 0.882973                      0.855493
# 44                      NaN                      0.153539
# 45                 0.952097                      0.094018
# 46                 0.983255                      0.288422
# 47                 0.958804                           NaN
# 48                 0.942558                      0.142434
# 49                      NaN                      0.149541
#
#     Five Year Avg Dividend Yield(%) Normalised
# 0                                     0.510444
# 1                                     0.208877
# 2                                     0.207572
# 3                                     0.477807
# 4                                     0.173629
# 5                                     0.000000
# 6                                          NaN
# 7                                     0.447781
# 8                                     0.271540
# 9                                     0.070496
# 10                                    0.291123
# 11                                         NaN
# 12                                         NaN
# 13                                    0.139687
# 14                                    0.494778
# 15                                         NaN
# 16                                    0.160574
# 17                                    0.394256
# 18                                    0.291123
# 19                                         NaN
# 20                                         NaN
# 21                                    1.000000
# 22                                         NaN
# 23                                    0.587467
# 24                                    0.353786
# 25                                    0.450392
# 26                                    0.133159
# 27                                    0.279373
# 28                                    0.338120
# 29                                    0.227154
# 30                                    0.178851
# 31                                    0.065274
# 32                                    0.385117
# 33                                    0.099217
# 34                                    0.207572
# 35                                    0.082245
# 36                                    0.300261
# 37                                    0.304178
# 38                                    0.053525
# 39                                    0.091384
# 40                                         NaN
# 41                                    0.135770
# 42                                         NaN
# 43                                    0.334204
# 44                                         NaN
# 45                                    0.120104
# 46                                    0.208877
# 47                                    0.849869
# 48                                    0.304178
# 49                                    0.046997

# %% [markdown]
# Compute Dividend Score

# %%
# Define weightage for each normalized dividend-related metric
# These weights determine the importance of each factor in the overall score
weights = {
    'Dividend Yield(%) Normalised': 0.3,
    'Dividend Rate Normalised': 0.2,
    'Payout Ratio Normalised': 0.2,
    'Five Year Avg Dividend Yield(%) Normalised': 0.2,
    'Earning Growth(%) Normalised': 0.1
}

# Calculate the final 'Dividend Score' for each stock:
# → multiply each normalized col by its corresponding weight
# → sum across all weighted cols to get a single composite score per stock
dividend_df['Dividend Score'] = dividend_df[[col for col in weights.keys()]].mul(list(weights.values())).sum(axis = 1)
dividend_df
# Out:
#    Ticker  Dividend Yield(%)  Dividend Rate  Payout Ratio  \
# 0     MMM              178.0           2.92     46.090000
# 1     AOS              209.0           1.38     36.660000
# 2     ABT              189.0           2.36     29.150000
# 3    ABBV              319.0           6.92    490.149970
# 4     ACN              263.0           6.52     48.720002
# 5    ADBE                NaN            NaN           NaN
# 6     AMD                NaN            NaN           NaN
# 7     AES              495.0           0.70     46.080002
# 8     AFL              209.0           2.32     29.430000
# 9       A               68.0           0.99     22.900000
# 10    APD              301.0           7.16    100.990000
# 11   ABNB                NaN            NaN           NaN
# 12   AKAM                NaN            NaN           NaN
# 13    ALB              176.0           1.62     57.970000
# 14    ARE              969.0           5.28    689.469960
# 15   ALGN                NaN            NaN           NaN
# 16   ALLE              123.0           2.04     27.200000
# 17    LNT              304.0           2.03     60.960000
# 18    ALL              205.0           4.00     12.710000
# 19  GOOGL               30.0           0.84      8.090000
# 20   GOOG               29.0           0.84      8.090000
# 21     MO              742.0           4.24     78.629994
# 22   AMZN                NaN            NaN           NaN
# 23   AMCR              632.0           0.51    158.590000
# 24    AEE              280.0           2.84     60.660000
# 25    AEP              317.0           3.80     54.470000
# 26    AXP               86.0           3.16     15.720001
# 27    AIG              236.0           1.80     30.580000
# 28    AMT              379.0           6.80    107.180000
# 29    AWK              253.0           3.31     55.979997
# 30    AMP              139.0           6.40     16.950001
# 31    AME               63.0           1.24     19.090000
# 32   AMGN              298.0           9.52     72.620004
# 33    APH               72.0           1.00     22.000000
# 34    ADI              168.0           3.96     97.199994
# 35    AON               87.0           2.98     22.719999
# 36    APA              462.0           1.00     34.600000
# 37    APO              153.0           2.04     35.400000
# 38   AAPL               38.0           1.04     13.670000
# 39   AMAT               76.0           1.84     19.810000
# 40    APP                NaN            NaN           NaN
# 41   APTV                NaN            NaN           NaN
# 42   ACGL                NaN            NaN           NaN
# 43    ADM              362.0           2.04     87.830000
# 44   ANET                NaN            NaN           NaN
# 45    AJG              105.0           2.60     40.730000
# 46    AIZ              147.0           3.20     19.500000
# 47      T              452.0           1.11     36.160000
# 48    ATO              202.0           3.48     47.230000
# 49   ADSK                NaN            NaN           NaN
#
#     Five Year Avg Dividend Yield(%)  Earning Growth(%)  \
# 0                              4.03              -37.5
# 1                              1.72               14.6
# 2                              1.71                NaN
# 3                              3.78              -88.7
# 4                              1.45              -15.5
# 5                              0.12               11.2
# 6                               NaN               60.3
# 7                              3.55               25.3
# 8                              2.20              -64.2
# 9                              0.66               21.6
# 10                             2.35                2.4
# 11                              NaN                1.6
# 12                              NaN              -17.4
# 13                             1.19                NaN
# 14                             3.91                NaN
# 15                              NaN              -49.7
# 16                             1.35                9.5
# 17                             3.14               99.6
# 18                             2.35              586.7
# 19                              NaN               35.3
# 20                              NaN               35.3
# 21                             7.78                5.2
# 22                              NaN               36.4
# 23                             4.62                NaN
# 24                             2.83                4.4
# 25                             3.57                0.6
# 26                             1.14               18.6
# 27                             2.26               31.0
# 28                             2.71                NaN
# 29                             1.86                8.1
# 30                             1.49               86.6
# 31                             0.62                8.8
# 32                             3.07               13.6
# 33                             0.88              102.1
# 34                             1.71               31.6
# 35                             0.75               34.4
# 36                             2.42               14.5
# 37                             2.45              -26.7
# 38                             0.53               91.2
# 39                             0.82                8.3
# 40                              NaN              168.8
# 41                             1.16                NaN
# 42                              NaN               39.1
# 43                             2.68              489.1
# 44                              NaN               15.0
# 45                             1.04              -25.2
# 46                             1.72              106.1
# 47                             6.63                NaN
# 48                             2.45                7.5
# 49                             0.48               12.3
#
#     Dividend Rate Normalised  Dividend Yield(%) Normalised  \
# 0                   0.267481                      0.158511
# 1                   0.096559                      0.191489
# 2                   0.205327                      0.170213
# 3                   0.711432                      0.308511
# 4                   0.667037                      0.248936
# 5                        NaN                           NaN
# 6                        NaN                           NaN
# 7                   0.021088                      0.495745
# 8                   0.200888                      0.191489
# 9                   0.053274                      0.041489
# 10                  0.738069                      0.289362
# 11                       NaN                           NaN
# 12                       NaN                           NaN
# 13                  0.123196                      0.156383
# 14                  0.529412                      1.000000
# 15                       NaN                           NaN
# 16                  0.169811                      0.100000
# 17                  0.168701                      0.292553
# 18                  0.387347                      0.187234
# 19                  0.036626                      0.001064
# 20                  0.036626                      0.000000
# 21                  0.413984                      0.758511
# 22                       NaN                           NaN
# 23                  0.000000                      0.641489
# 24                  0.258602                      0.267021
# 25                  0.365150                      0.306383
# 26                  0.294118                      0.060638
# 27                  0.143174                      0.220213
# 28                  0.698113                      0.372340
# 29                  0.310766                      0.238298
# 30                  0.653718                      0.117021
# 31                  0.081021                      0.036170
# 32                  1.000000                      0.286170
# 33                  0.054384                      0.045745
# 34                  0.382908                      0.147872
# 35                  0.274140                      0.061702
# 36                  0.054384                      0.460638
# 37                  0.169811                      0.131915
# 38                  0.058824                      0.009574
# 39                  0.147614                      0.050000
# 40                       NaN                           NaN
# 41                       NaN                           NaN
# 42                       NaN                           NaN
# 43                  0.169811                      0.354255
# 44                       NaN                           NaN
# 45                  0.231964                      0.080851
# 46                  0.298557                      0.125532
# 47                  0.066593                      0.450000
# 48                  0.329634                      0.184043
# 49                       NaN                           NaN
#
#     Payout Ratio Normalised  Earning Growth(%) Normalised  \
# 0                  0.944231                      0.075807
# 1                  0.958070                      0.152946
# 2                  0.969092                           NaN
# 3                  0.292524                      0.000000
# 4                  0.940371                      0.108380
# 5                       NaN                      0.147912
# 6                       NaN                      0.220610
# 7                  0.944245                      0.168789
# 8                  0.968681                      0.036275
# 9                  0.978265                      0.163311
# 10                 0.863659                      0.134883
# 11                      NaN                      0.133699
# 12                      NaN                      0.105567
# 13                 0.926796                           NaN
# 14                 0.000000                           NaN
# 15                      NaN                      0.057744
# 16                 0.971954                      0.145395
# 17                 0.922407                      0.278798
# 18                 0.993220                      1.000000
# 19                 1.000000                      0.183595
# 20                 1.000000                      0.183595
# 21                 0.896475                      0.139029
# 22                      NaN                      0.185224
# 23                 0.779125                           NaN
# 24                 0.922848                      0.137844
# 25                 0.931932                      0.132218
# 26                 0.988802                      0.158869
# 27                 0.966993                      0.177228
# 28                 0.854575                           NaN
# 29                 0.929716                      0.143322
# 30                 0.986997                      0.259550
# 31                 0.983856                      0.144359
# 32                 0.905295                      0.151466
# 33                 0.979586                      0.282499
# 34                 0.869221                      0.178117
# 35                 0.978529                      0.182262
# 36                 0.961094                      0.152798
# 37                 0.959920                      0.091797
# 38                 0.991811                      0.266361
# 39                 0.982800                      0.143619
# 40                      NaN                      0.381256
# 41                      NaN                           NaN
# 42                      NaN                      0.189221
# 43                 0.882973                      0.855493
# 44                      NaN                      0.153539
# 45                 0.952097                      0.094018
# 46                 0.983255                      0.288422
# 47                 0.958804                           NaN
# 48                 0.942558                      0.142434
# 49                      NaN                      0.149541
#
#     Five Year Avg Dividend Yield(%) Normalised  Dividend Score
# 0                                     0.510444        0.399565
# 1                                     0.208877        0.325443
# 2                                     0.207572        0.327462
# 3                                     0.477807        0.388906
# 4                                     0.173629        0.441726
# 5                                     0.000000        0.014791
# 6                                          NaN        0.022061
# 7                                     0.447781        0.448225
# 8                                     0.271540        0.349296
# 9                                     0.070496        0.249185
# 10                                    0.291123        0.478867
# 11                                         NaN        0.013370
# 12                                         NaN        0.010557
# 13                                    0.139687        0.284851
# 14                                    0.494778        0.504838
# 15                                         NaN        0.005774
# 16                                    0.160574        0.305007
# 17                                    0.394256        0.412719
# 18                                    0.291123        0.490508
# 19                                         NaN        0.226004
# 20                                         NaN        0.225685
# 21                                    1.000000        0.703548
# 22                                         NaN        0.018522
# 23                                    0.587467        0.465765
# 24                                    0.353786        0.400938
# 25                                    0.450392        0.454631
# 26                                    0.133159        0.317294
# 27                                    0.279373        0.361695
# 28                                    0.338120        0.489864
# 29                                    0.227154        0.379349
# 30                                    0.178851        0.424975
# 31                                    0.065274        0.251317
# 32                                    0.385117        0.559080
# 33                                    0.099217        0.268611
# 34                                    0.207572        0.354114
# 35                                    0.082245        0.303720
# 36                                    0.300261        0.416619
# 37                                    0.304178        0.335536
# 38                                    0.053525        0.250340
# 39                                    0.091384        0.273721
# 40                                         NaN        0.038126
# 41                                    0.135770        0.027154
# 42                                         NaN        0.018922
# 43                                    0.334204        0.469223
# 44                                         NaN        0.015354
# 45                                    0.120104        0.294490
# 46                                    0.208877        0.364640
# 47                                    0.849869        0.510053
# 48                                    0.304178        0.384730
# 49                                    0.046997        0.024354

# %% [markdown]
# Rank Stocks

# %%
# Sort all stocks in descending order based on their 'Dividend Score'
dividend_df = dividend_df.sort_values(by='Dividend Score', ascending=False)

# Reset the index after sorting to maintain a clean, continuous order
dividend_df.reset_index(drop=True, inplace=True)
dividend_df.head(10)
# Out:
#   Ticker  Dividend Yield(%)  Dividend Rate  Payout Ratio  \
# 0     MO              742.0           4.24     78.629994
# 1   AMGN              298.0           9.52     72.620004
# 2      T              452.0           1.11     36.160000
# 3    ARE              969.0           5.28    689.469960
# 4    ALL              205.0           4.00     12.710000
# 5    AMT              379.0           6.80    107.180000
# 6    APD              301.0           7.16    100.990000
# 7    ADM              362.0           2.04     87.830000
# 8   AMCR              632.0           0.51    158.590000
# 9    AEP              317.0           3.80     54.470000
#
#    Five Year Avg Dividend Yield(%)  Earning Growth(%)  \
# 0                             7.78                5.2
# 1                             3.07               13.6
# 2                             6.63                NaN
# 3                             3.91                NaN
# 4                             2.35              586.7
# 5                             2.71                NaN
# 6                             2.35                2.4
# 7                             2.68              489.1
# 8                             4.62                NaN
# 9                             3.57                0.6
#
#    Dividend Rate Normalised  Dividend Yield(%) Normalised  \
# 0                  0.413984                      0.758511
# 1                  1.000000                      0.286170
# 2                  0.066593                      0.450000
# 3                  0.529412                      1.000000
# 4                  0.387347                      0.187234
# 5                  0.698113                      0.372340
# 6                  0.738069                      0.289362
# 7                  0.169811                      0.354255
# 8                  0.000000                      0.641489
# 9                  0.365150                      0.306383
#
#    Payout Ratio Normalised  Earning Growth(%) Normalised  \
# 0                 0.896475                      0.139029
# 1                 0.905295                      0.151466
# 2                 0.958804                           NaN
# 3                 0.000000                           NaN
# 4                 0.993220                      1.000000
# 5                 0.854575                           NaN
# 6                 0.863659                      0.134883
# 7                 0.882973                      0.855493
# 8                 0.779125                           NaN
# 9                 0.931932                      0.132218
#
#    Five Year Avg Dividend Yield(%) Normalised  Dividend Score
# 0                                    1.000000        0.703548
# 1                                    0.385117        0.559080
# 2                                    0.849869        0.510053
# 3                                    0.494778        0.504838
# 4                                    0.291123        0.490508
# 5                                    0.338120        0.489864
# 6                                    0.291123        0.478867
# 7                                    0.334204        0.469223
# 8                                    0.587467        0.465765
# 9                                    0.450392        0.454631

# %% [markdown]
# Determine Position Size

# %%
# Get total investment amount from user
portfolio_size = int(input("Enter the investment amount: "))

# Calculate equal position size per stock
position_size = portfolio_size / len(dividend_df.index)
position_size

# %% [markdown]
# Calculate Number of Shares

# %%
# Fetch latest price for each ticker
dividend_df['Latest Price'] = dividend_df['Ticker'].apply(
    lambda x: yf.Ticker(x).history(period='1d')['Close'].iloc[-1]
)

# Calc number of shares to buy for each stock based on position size
# Use floor to avoid fractional shares
dividend_df['Number of Shares to buy'] = dividend_df['Latest Price'].apply(lambda price: math.floor( 
    position_size / price
))
dividend_df
